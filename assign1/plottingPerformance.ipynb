# %% [markdown]
# ### Question 5 - Plotting Parallel vs Serial Time

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Open results.csv
df = pd.read_csv('results.csv')

# Plot n versus Parallel Time and Serial Time
plt.plot(df['n'], df['Parallel Time'], label='Parallel Time')
plt.plot(df['n'], df['Serial Time'], label='Serial Time')
plt.xlabel('n')
plt.ylabel('Time (s)')
plt.title('n vs. Time')
plt.legend()
plt.show()

# %%
# Open resultsClosest.csv
df = pd.read_csv('resultsClosest.csv')

# Plot n versus Serial Time and Parallel Time and Improved Parallel Time
plt.plot(df['n'], df['Serial Time'], label='Serial Time')
plt.plot(df['n'], df['Parallel Time'], label='Parallel Time')
plt.plot(df['n'], df['Improved Parallel Time'], label='Improved Parallel Time')
plt.xlabel('n')
plt.ylabel('Time (s)')
plt.title('n vs. Time')
plt.legend()
plt.show()
